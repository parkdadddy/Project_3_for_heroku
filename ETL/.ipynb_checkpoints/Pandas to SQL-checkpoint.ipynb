# %%
from sqlalchemy import create_engine
import psycopg2

# %%
import pandas as pd
import requests
import json

# %%
final_rent_df = pd.read_csv('RentFinal.csv')
final_rent_df
# Out:
#      Unnamed: 0                                  SA2Name  var1  var2  var3  \
# 0             0                     Dawesville - Bouvard  0.86  0.15  1.15
# 1             1                        Falcon - Wannanup  0.86  0.15  1.15
# 2             2                              Greenfields  0.57  0.18  0.86
# 3             3                     Halls Head - Erskine  0.63  0.15  0.88
# 4             4                                 Mandurah  0.57  0.18  0.86
# ..          ...                                      ...   ...   ...   ...
# 168         168                         Rockingham Lakes  0.00  0.00  0.00
# 169         169                  Safety Bay - Shoalwater  0.86  0.00  0.86
# 170         170  Singleton - Golden Bay - Secret Harbour  0.37  0.13  0.55
# 171         171                                  Waikiki  0.86  0.15  1.15
# 172         172                                  Warnbro  0.63  0.15  0.88
#
#     Rent1 Rent2 Rent3
# 0    $174  $324  $374
# ...

# %%
final_rent_df.dtypes
# Out:
# Unnamed: 0      int64
# SA2Name        object
# var1          float64
# var2          float64
# var3          float64
# Rent1          object
# Rent2          object
# Rent3          object
# dtype: object

# %%
connection_string = "postgres:sql2007@localhost:5432/project-3-gentrification"
engine = create_engine(f'postgresql://{connection_string}')

# %%
final_rent_df.to_sql('rent', engine, if_exists='fail');
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...
