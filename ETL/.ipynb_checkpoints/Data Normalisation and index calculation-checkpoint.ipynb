# %%
from sklearn import preprocessing
import numpy as np
import pandas as pd
import scipy.stats as stats

# %%
merged_df  = pd.read_csv('Final_merged.csv')

# %%
merged_df.head(60)
# Out:
#     Unnamed: 0   SA2 Code                                  SA2 Name  Rent2006  \
# 0           16  503021037                           Kings Park (WA)        74
# 1          137  507011158                              North Coogee        74
# 2           67  505021088                      Innaloo - Doubleview        74
# 3          145  507021165                                 Fremantle        74
# 4          128  506071146                       Manning - Waterford        74
# 5           15  503011036              Swanbourne - Mount Claremont        74
# 6          146  507021166                         Fremantle - South        74
# 7           30  504021051                 Helena Valley - Koongamia        74
# 8          106  506031124               Bentley - Wilson - St James        74
# 9          134  507011153                                Coolbellup        74
# 10          14  503011035             Nedlands - Dalkeith - Crawley       174
# ...

# %%
#Normalise attributes percentages
rent_2006_2016_array = np.array(merged_df['Rent%2006_2016'])
normalized_rent_2006_2016 = preprocessing.normalize([rent_2006_2016_array])
normalized_rent_2006_2016
# Out:
# array([[0.39188218, 0.21249017, 0.21249017, 0.21249017, 0.21249017,
#         0.39188218, 0.21249017, 0.21249017, 0.21249017, 0.13404754,
#         0.07149202, 0.05328803, 0.04799233, 0.04799233, 0.21249017,
#         0.07149202, 0.07149202, 0.07149202, 0.07149202, 0.07149202,
#         0.07149202, 0.07149202, 0.07149202, 0.07149202, 0.07149202,
#         0.07149202, 0.07149202, 0.05825276, 0.05825276, 0.05825276,
#         0.05825276, 0.04799233, 0.04799233, 0.04799233, 0.04799233,
#         0.04799233, 0.04799233, 0.15655428, 0.04799233, 0.04766135,
#         0.04766135, 0.03872484, 0.03806288, 0.03806288, 0.03806288,
#         0.03806288, 0.03806288, 0.03806288, 0.07149202, 0.02912638,
#         0.03740092, 0.03806288, 0.03806288, 0.03806288, 0.03806288,
#         0.03806288, 0.02846441, 0.02846441, 0.13404754, 0.02846441,
#         0.03309816, 0.02846441, 0.03309816, 0.02945736, 0.02846441,
#         0.02945736, 0.02912638, 0.02912638, 0.02945736, 0.02846441,
# ...

# %%
# merged_df['normalised_rent_2006_2016'] = normalized_rent_2006_2016

# %%
rent_2006_2011_array = np.array(merged_df['Rent%2006-2011'])
normalized_rent_2006_2011 = preprocessing.normalize([rent_2006_2011_array])
# normalized_rent_2006_2011

# %%
rent_2011_2016_array = np.array(merged_df['Rent%2011-2016'])
normalized_rent_2011_2016 = preprocessing.normalize([rent_2011_2016_array])
# normalized_rent_2011_2016

# %%
house_2006_2016_array = np.array(merged_df['House%2006_2016'])
normalized_house_2006_2016 = preprocessing.normalize([house_2006_2016_array])
# normalized_house_2006_2016

# %%
house_2006_2011_array = np.array(merged_df['House%2006_2011'])
normalized_house_2006_2011 = preprocessing.normalize([house_2006_2011_array])
# normalized_house_2006_2011

# %%
house_2011_2016_array = np.array(merged_df['House%2011_2016'])
normalized_house_2011_2016 = preprocessing.normalize([house_2011_2016_array])
# normalized_house_2011_2016

# %%
inc_2006_2016_array = np.array(merged_df['Income%2006_2016'])
normalized_income_2006_2016 = preprocessing.normalize([inc_2006_2016_array])
# normalized_income_2006_2016

# %%
inc_2006_2011_array = np.array(merged_df['Income%2006_2011'])
normalized_income_2006_2011 = preprocessing.normalize([inc_2006_2011_array])
# normalized_income_2006_2011

# %%
inc_2011_2016_array = np.array(merged_df['Income%2011_2016'])
normalized_income_2011_2016 = preprocessing.normalize([inc_2011_2016_array])
# normalized_income_2011_2016

# %%
bach_2006_2016_array = np.array(merged_df['Bacherlor%2006-2016'])
normalized_bachelor_2006_2016 = preprocessing.normalize([bach_2006_2016_array])
# normalized_bachelor_2006_2016

# %%
bach_2006_2011_array = np.array(merged_df['Bachelor%2006-2011'])
normalized_bachelor_2006_2011 = preprocessing.normalize([bach_2006_2011_array])
# normalized_bachelor_2006_2011

# %%
bach_2011_2016_array = np.array(merged_df['Bacherlor%2011-2016'])
normalized_bachelor_2011_2016 = preprocessing.normalize([bach_2011_2016_array])
# normalized_bachelor_2011_2016
